# %%
import torch
from torch import nn
from torch.nn import functional as func
from torch.nn.utils import rnn
from torch.autograd import Variable
import numpy
import pickle
from sklearn.metrics import accuracy_score
from utils import Dataset, get_script_short_name
import time

hparams = {
    'learning_rate': 0.001,
    'max_epoch': 20,
    'display_step': 20,
    'emb_dim': 300,
    'conv_win': 3,
    'repr_dim': 300,
    'fc1_dim': 300,
    'n_classes': 2,
    'batch_size': 400
}


class LSTM(nn.Module):
    def __init__(self, emb_layer):
        super(LSTM, self).__init__()
        self.emb_layer = emb_layer
        self.lstm_layer = nn.LSTM(input_size=hparams['emb_dim'], hidden_size=int(hparams['repr_dim'] / 2),
                                  batch_first=True, bidirectional=True)

    def forward(self, x, lengths):
        embs = self.emb_layer(x)
        embs_sort, lengths_sort, unsort_idx = self.sort_batch(embs, lengths)
        seq = rnn.pack_padded_sequence(embs_sort, lengths_sort.cpu().numpy(), batch_first=True)
        hs, (hn, cn) = self.lstm_layer(seq)
        out = cn.permute(1, 2, 0).contiguous().view(-1, hparams['repr_dim'])
        return out[unsort_idx]

    @staticmethod
    def sort_batch(x, l):
        l = torch.from_numpy(numpy.asarray(l)).cuda()
        l_sorted, sidx = l.sort(0, descending=True)
        x_sorted = x[sidx]
        _, unsort_idx = sidx.sort()
        return x_sorted, l_sorted, unsort_idx


class Model(nn.Module):
    def __init__(self, emb_layer):
        super(Model, self).__init__()
        self.lstm = LSTM(emb_layer)
        self.fc1 = nn.Linear(hparams['repr_dim'] * 2, hparams['fc1_dim'])
        self.fc2 = nn.Linear(hparams['fc1_dim'], hparams['n_classes'])

    def forward(self, q1, q2, q1_len, q2_len):
        r1 = self.lstm(q1, q1_len)
        r2 = self.lstm(q2, q2_len)
        joint = torch.cat(((r1 - r2).abs(), r1 * r2), dim=1)
        joint = torch.tanh(self.fc1(joint))
        out = self.fc2(joint)
        return out


def run_batch(b_data, b_lengths, model, optimizer=None):
    q1 = Variable(torch.from_numpy(b_data['q1']).cuda())
    q2 = Variable(torch.from_numpy(b_data['q2']).cuda())
    outputs = model(q1, q2, b_lengths['q1'], b_lengths['q2'])
    if optimizer:
        y = Variable(torch.from_numpy(b_data['y']).cuda())
        optimizer.zero_grad()
        loss = func.cross_entropy(outputs, y)
        loss.backward()
        optimizer.step()
        return loss.data.item()
    else:
        _, predicted = outputs.data.max(1)
        prob = func.softmax(outputs, dim=1).data
        return predicted, prob[:, 1]


def run_epoch_eval(dataset, model, output_file=''):
    all_plabels, all_pscores = [], []
    batches, batch_lengths = dataset.get_batches(hparams['batch_size'], ('q1', 'q2', 'y'))
    for b_data, b_lengths in zip(batches, batch_lengths):
        plabels, pscores = run_batch(b_data,b_lengths, model)
        all_plabels.extend(plabels.cpu().numpy().tolist())
        all_pscores.extend(pscores.cpu().numpy().tolist())
    if output_file:
        with open(output_file, 'a') as f:
            for s in all_pscores:
                f.write(f'{s:.4f}\n')
    return accuracy_score(dataset.get_data_item('y'), all_plabels)


def run():
    print('Loading data...')
    with open('data/data_emb', 'rb') as f:
        all_sets, embs, word2idx = pickle.load(f)
    emb_layer = nn.Embedding(embs.shape[0], embs.shape[1])
    emb_layer.weight = nn.Parameter(torch.from_numpy(embs))
    model = Model(emb_layer).cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=hparams['learning_rate'])
    train_set = Dataset(all_sets[0], shuffle=True, pad_keys=('q1', 'q2'))
    dev_set = Dataset(all_sets[1], shuffle=False, pad_keys=('q1', 'q2'))
    test_set = Dataset(all_sets[2], shuffle=False, pad_keys=('q1', 'q2'))
    step = 0
    sum_loss = 0
    dev_best = 0
    test_score = 0
    print("Starting training...")
    print(hparams)
    start_time = time.time()
    for epoch in range(hparams['max_epoch']):
        batches, batch_lengths = train_set.get_batches(hparams['batch_size'], ('q1', 'q2', 'y'))
        for b_data, b_lengths in zip(batches, batch_lengths):
            sum_loss += run_batch(b_data, b_lengths, model, optimizer)
            step += 1
            if step % hparams['display_step'] == 0:
                avg_loss = sum_loss / hparams['display_step']
                sum_loss = 0
                dev_score = run_epoch_eval(dev_set, model)
                out_str = f'Epoc {epoch} iter {step} took {time.time() - start_time:.1f}s\n' \
                          f'loss:\t{avg_loss:.5f}\tdev score:\t{dev_score:.4f}'
                if dev_score > dev_best:
                    dev_best = dev_score
                    output_file = f'pred/bilstm.pred'
                    test_score = run_epoch_eval(test_set, model, output_file)
                    out_str += f'\t*** New best dev ***\ttest score:\t{test_score:.4f}'
                print(out_str)
                start_time = time.time()
    print('Best model on dev: dev:{:.4f}\ttest:{:.4f}'.format(dev_best, test_score))


if __name__ == '__main__':
    run()
# Out:
# Loading data...
# Starting training...
# {'learning_rate': 0.001, 'max_epoch': 20, 'display_step': 20, 'emb_dim': 300, 'conv_win': 3, 'repr_dim': 300, 'fc1_dim': 300, 'n_classes': 2, 'batch_size': 400}
# Epoc 0 iter 20 took 9.6s
# loss:	0.60698	dev score:	0.7035	*** New best dev ***	test score:	0.6971
# Epoc 0 iter 40 took 7.4s
# loss:	0.54456	dev score:	0.7164	*** New best dev ***	test score:	0.7099
# Epoc 0 iter 60 took 7.8s
# loss:	0.53002	dev score:	0.7535	*** New best dev ***	test score:	0.7446
# Epoc 0 iter 80 took 7.5s
# loss:	0.49929	dev score:	0.7596	*** New best dev ***	test score:	0.7535
# Epoc 0 iter 100 took 7.6s
# loss:	0.47761	dev score:	0.7741	*** New best dev ***	test score:	0.7709
# Epoc 0 iter 120 took 7.4s
# loss:	0.45796	dev score:	0.7554
# Epoc 0 iter 140 took 7.3s
# loss:	0.45583	dev score:	0.7860	*** New best dev ***	test score:	0.7784
# Epoc 0 iter 160 took 7.2s
# loss:	0.44923	dev score:	0.7920	*** New best dev ***	test score:	0.7858
# Epoc 0 iter 180 took 7.2s
# loss:	0.43700	dev score:	0.7908
# Epoc 0 iter 200 took 7.2s
# loss:	0.42638	dev score:	0.7984	*** New best dev ***	test score:	0.7930
# Epoc 0 iter 220 took 7.4s
# loss:	0.42564	dev score:	0.7990	*** New best dev ***	test score:	0.7933
# Epoc 0 iter 240 took 7.5s
# loss:	0.42238	dev score:	0.8055	*** New best dev ***	test score:	0.7987
# Epoc 0 iter 260 took 7.5s
# loss:	0.43044	dev score:	0.8038
# Epoc 0 iter 280 took 7.5s
# loss:	0.41425	dev score:	0.8093	*** New best dev ***	test score:	0.8027
# Epoc 0 iter 300 took 7.5s
# loss:	0.40551	dev score:	0.8092
# Epoc 0 iter 320 took 7.3s
# loss:	0.40296	dev score:	0.8131	*** New best dev ***	test score:	0.8075
# Epoc 0 iter 340 took 7.4s
# loss:	0.40362	dev score:	0.8164	*** New best dev ***	test score:	0.8087
# Epoc 0 iter 360 took 8.1s
# loss:	0.39767	dev score:	0.8198	*** New best dev ***	test score:	0.8107
# Epoc 0 iter 380 took 7.2s
# loss:	0.39981	dev score:	0.8184
# Epoc 0 iter 400 took 7.3s
# loss:	0.39298	dev score:	0.8222	*** New best dev ***	test score:	0.8153
# Epoc 0 iter 420 took 7.6s
# loss:	0.39739	dev score:	0.8125
# Epoc 0 iter 440 took 7.4s
# loss:	0.40093	dev score:	0.8234	*** New best dev ***	test score:	0.8158
# Epoc 0 iter 460 took 7.4s
# loss:	0.38672	dev score:	0.8274	*** New best dev ***	test score:	0.8204
# Epoc 0 iter 480 took 7.2s
# loss:	0.37733	dev score:	0.8298	*** New best dev ***	test score:	0.8232
# Epoc 0 iter 500 took 7.4s
# loss:	0.38225	dev score:	0.8267
# Epoc 0 iter 520 took 7.2s
# loss:	0.37950	dev score:	0.8320	*** New best dev ***	test score:	0.8256
# Epoc 0 iter 540 took 7.3s
# loss:	0.38801	dev score:	0.8244
# Epoc 0 iter 560 took 7.4s
# loss:	0.37418	dev score:	0.8313
# Epoc 0 iter 580 took 7.3s
# loss:	0.36264	dev score:	0.8313
# Epoc 0 iter 600 took 7.2s
# loss:	0.37661	dev score:	0.8318
# Epoc 0 iter 620 took 7.4s
# loss:	0.36821	dev score:	0.8354	*** New best dev ***	test score:	0.8310
# Epoc 0 iter 640 took 7.5s
# loss:	0.36499	dev score:	0.8378	*** New best dev ***	test score:	0.8330
# Epoc 0 iter 660 took 7.5s
# loss:	0.36605	dev score:	0.8354
# Epoc 0 iter 680 took 7.5s
# loss:	0.35968	dev score:	0.8327
# Epoc 0 iter 700 took 7.3s
# loss:	0.36377	dev score:	0.8390	*** New best dev ***	test score:	0.8347
# Epoc 0 iter 720 took 7.2s
# loss:	0.36834	dev score:	0.8389
# Epoc 0 iter 740 took 7.2s
# loss:	0.35731	dev score:	0.8426	*** New best dev ***	test score:	0.8360
# Epoc 0 iter 760 took 7.4s
# loss:	0.35393	dev score:	0.8421
# Epoc 0 iter 780 took 7.3s
# loss:	0.34774	dev score:	0.8426
# Epoc 0 iter 800 took 7.3s
# loss:	0.34272	dev score:	0.8435	*** New best dev ***	test score:	0.8386
# Epoc 1 iter 820 took 9.0s
# loss:	0.31970	dev score:	0.8437	*** New best dev ***	test score:	0.8394
# Epoc 1 iter 840 took 7.5s
# loss:	0.28425	dev score:	0.8458	*** New best dev ***	test score:	0.8392
# Epoc 1 iter 860 took 7.4s
# loss:	0.28607	dev score:	0.8451
# Epoc 1 iter 880 took 7.3s
# loss:	0.27643	dev score:	0.8436
# Epoc 1 iter 900 took 7.6s
# loss:	0.28006	dev score:	0.8383
# Epoc 1 iter 920 took 7.2s
# loss:	0.28780	dev score:	0.8432
# Epoc 1 iter 940 took 7.5s
# loss:	0.28495	dev score:	0.8419
# Epoc 1 iter 960 took 7.6s
# loss:	0.27569	dev score:	0.8472	*** New best dev ***	test score:	0.8431
# Epoc 1 iter 980 took 7.5s
# loss:	0.28253	dev score:	0.8481	*** New best dev ***	test score:	0.8428
# Epoc 1 iter 1000 took 7.2s
# loss:	0.27939	dev score:	0.8463
# Epoc 1 iter 1020 took 7.4s
# loss:	0.28632	dev score:	0.8489	*** New best dev ***	test score:	0.8437
# Epoc 1 iter 1040 took 7.5s
# loss:	0.27325	dev score:	0.8491	*** New best dev ***	test score:	0.8437
# Epoc 1 iter 1060 took 7.7s
# loss:	0.29187	dev score:	0.8490
# Epoc 1 iter 1080 took 7.2s
# loss:	0.28611	dev score:	0.8477
# Epoc 1 iter 1100 took 7.9s
# loss:	0.29032	dev score:	0.8440
# Epoc 1 iter 1120 took 7.5s
# loss:	0.26803	dev score:	0.8508	*** New best dev ***	test score:	0.8476
# Epoc 1 iter 1140 took 7.2s
# loss:	0.28804	dev score:	0.8521	*** New best dev ***	test score:	0.8493
# Epoc 1 iter 1160 took 7.1s
# loss:	0.27275	dev score:	0.8523	*** New best dev ***	test score:	0.8471
# Epoc 1 iter 1180 took 7.5s
# loss:	0.27846	dev score:	0.8529	*** New best dev ***	test score:	0.8490
# Epoc 1 iter 1200 took 7.2s
# loss:	0.27448	dev score:	0.8503
# Epoc 1 iter 1220 took 7.7s
# loss:	0.28040	dev score:	0.8522
# Epoc 1 iter 1240 took 7.8s
# loss:	0.27969	dev score:	0.8499
# Epoc 1 iter 1260 took 7.4s
# loss:	0.27890	dev score:	0.8523
# Epoc 1 iter 1280 took 7.5s
# loss:	0.27827	dev score:	0.8532	*** New best dev ***	test score:	0.8512
# Epoc 1 iter 1300 took 7.2s
# loss:	0.28045	dev score:	0.8534	*** New best dev ***	test score:	0.8514
# Epoc 1 iter 1320 took 7.4s
# loss:	0.26719	dev score:	0.8534
# Epoc 1 iter 1340 took 7.2s
# loss:	0.27198	dev score:	0.8523
# Epoc 1 iter 1360 took 7.3s
# loss:	0.27934	dev score:	0.8533
# Epoc 1 iter 1380 took 7.4s
# loss:	0.27954	dev score:	0.8536	*** New best dev ***	test score:	0.8525
# Epoc 1 iter 1400 took 7.2s
# loss:	0.29510	dev score:	0.8516
# Epoc 1 iter 1420 took 7.5s
# loss:	0.28111	dev score:	0.8539	*** New best dev ***	test score:	0.8522
# Epoc 1 iter 1440 took 7.4s
# loss:	0.26560	dev score:	0.8564	*** New best dev ***	test score:	0.8541
# Epoc 1 iter 1460 took 7.4s
# loss:	0.28135	dev score:	0.8533
# Epoc 1 iter 1480 took 7.2s
# loss:	0.26615	dev score:	0.8576	*** New best dev ***	test score:	0.8551
# Epoc 1 iter 1500 took 7.5s
# loss:	0.27429	dev score:	0.8552
# Epoc 1 iter 1520 took 7.6s
# loss:	0.27203	dev score:	0.8534
# Epoc 1 iter 1540 took 7.6s
# loss:	0.27060	dev score:	0.8547
# Epoc 1 iter 1560 took 7.5s
# loss:	0.27547	dev score:	0.8570
# Epoc 1 iter 1580 took 7.5s
# loss:	0.27843	dev score:	0.8589	*** New best dev ***	test score:	0.8571
# Epoc 1 iter 1600 took 7.3s
# loss:	0.27066	dev score:	0.8583
# Epoc 2 iter 1620 took 8.8s
# loss:	0.25222	dev score:	0.8586
# Epoc 2 iter 1640 took 7.4s
# loss:	0.16772	dev score:	0.8590	*** New best dev ***	test score:	0.8575
# Epoc 2 iter 1660 took 7.7s
# loss:	0.16520	dev score:	0.8558
# Epoc 2 iter 1680 took 7.4s
# loss:	0.17116	dev score:	0.8541
# Epoc 2 iter 1700 took 7.3s
# loss:	0.17256	dev score:	0.8556
# Epoc 2 iter 1720 took 7.2s
# loss:	0.17240	dev score:	0.8545
# Epoc 2 iter 1740 took 7.2s
# loss:	0.18349	dev score:	0.8501
# Epoc 2 iter 1760 took 7.3s
# loss:	0.17735	dev score:	0.8551
# Epoc 2 iter 1780 took 7.3s
# loss:	0.17692	dev score:	0.8520
# Epoc 2 iter 1800 took 7.6s
# loss:	0.17698	dev score:	0.8577
# Epoc 2 iter 1820 took 7.3s
# loss:	0.18342	dev score:	0.8566
# Epoc 2 iter 1840 took 7.6s
# loss:	0.19040	dev score:	0.8564
# Epoc 2 iter 1860 took 7.4s
# loss:	0.18706	dev score:	0.8558
# Epoc 2 iter 1880 took 7.2s
# loss:	0.19017	dev score:	0.8564
# Epoc 2 iter 1900 took 7.6s
# loss:	0.18277	dev score:	0.8583
# Epoc 2 iter 1920 took 7.2s
# loss:	0.17725	dev score:	0.8564
# Epoc 2 iter 1940 took 7.3s
# loss:	0.18572	dev score:	0.8481
# Epoc 2 iter 1960 took 7.3s
# loss:	0.18917	dev score:	0.8586
# Epoc 2 iter 1980 took 7.2s
# loss:	0.18720	dev score:	0.8552
# Epoc 2 iter 2000 took 7.6s
# loss:	0.18109	dev score:	0.8571
# Epoc 2 iter 2020 took 7.6s
# loss:	0.18626	dev score:	0.8563
# Epoc 2 iter 2040 took 7.7s
# loss:	0.18231	dev score:	0.8569
# Epoc 2 iter 2060 took 7.4s
# loss:	0.18826	dev score:	0.8531
# Epoc 2 iter 2080 took 7.2s
# loss:	0.19532	dev score:	0.8587
# Epoc 2 iter 2100 took 7.7s
# loss:	0.19385	dev score:	0.8583
# Epoc 2 iter 2120 took 7.2s
# loss:	0.18499	dev score:	0.8574
# Epoc 2 iter 2140 took 7.3s
# loss:	0.18935	dev score:	0.8580
# Epoc 2 iter 2160 took 7.4s
# loss:	0.19660	dev score:	0.8601	*** New best dev ***	test score:	0.8589
# Epoc 2 iter 2180 took 7.5s
# loss:	0.18681	dev score:	0.8560
# Epoc 2 iter 2200 took 7.6s
# loss:	0.18184	dev score:	0.8605	*** New best dev ***	test score:	0.8579
# Epoc 2 iter 2220 took 7.2s
# loss:	0.18395	dev score:	0.8613	*** New best dev ***	test score:	0.8594
# Epoc 2 iter 2240 took 7.3s
# loss:	0.19042	dev score:	0.8598
# Epoc 2 iter 2260 took 7.3s
# loss:	0.18868	dev score:	0.8591
# Epoc 2 iter 2280 took 7.8s
# loss:	0.18416	dev score:	0.8553
# Epoc 2 iter 2300 took 7.2s
# loss:	0.19111	dev score:	0.8597
# Epoc 2 iter 2320 took 7.2s
# loss:	0.18322	dev score:	0.8592
# Epoc 2 iter 2340 took 7.4s
# loss:	0.18866	dev score:	0.8573
# Epoc 2 iter 2360 took 7.2s
# loss:	0.18959	dev score:	0.8586
# Epoc 2 iter 2380 took 7.5s
# loss:	0.19189	dev score:	0.8587
# Epoc 2 iter 2400 took 7.4s
# loss:	0.19749	dev score:	0.8610
# Epoc 2 iter 2420 took 7.6s
# loss:	0.19186	dev score:	0.8602
# Epoc 3 iter 2440 took 8.8s
# loss:	0.13311	dev score:	0.8608
# Epoc 3 iter 2460 took 7.4s
# loss:	0.09949	dev score:	0.8574
# Epoc 3 iter 2480 took 7.4s
# loss:	0.10800	dev score:	0.8555
# Epoc 3 iter 2500 took 7.5s
# loss:	0.10905	dev score:	0.8553
# Epoc 3 iter 2520 took 7.4s
# loss:	0.11098	dev score:	0.8571
# Epoc 3 iter 2540 took 7.2s
# loss:	0.10598	dev score:	0.8555
# Epoc 3 iter 2560 took 7.4s
# loss:	0.11398	dev score:	0.8569
# Epoc 3 iter 2580 took 7.5s
# loss:	0.11237	dev score:	0.8591
# Epoc 3 iter 2600 took 7.3s
# loss:	0.10427	dev score:	0.8569
# Epoc 3 iter 2620 took 7.5s
# loss:	0.10253	dev score:	0.8550
# Epoc 3 iter 2640 took 7.2s
# loss:	0.11897	dev score:	0.8573
# Epoc 3 iter 2660 took 7.3s
# loss:	0.11701	dev score:	0.8572
# Epoc 3 iter 2680 took 7.2s
# loss:	0.11680	dev score:	0.8608
# Epoc 3 iter 2700 took 7.5s
# loss:	0.12104	dev score:	0.8562
# Epoc 3 iter 2720 took 7.3s
# loss:	0.10876	dev score:	0.8577
# Epoc 3 iter 2740 took 7.5s
# loss:	0.11016	dev score:	0.8576
# Epoc 3 iter 2760 took 7.2s
# loss:	0.11323	dev score:	0.8579
# Epoc 3 iter 2780 took 7.5s
# loss:	0.11961	dev score:	0.8583
# Epoc 3 iter 2800 took 7.5s
# loss:	0.12326	dev score:	0.8585
# Epoc 3 iter 2820 took 7.3s
# loss:	0.11928	dev score:	0.8569
# Epoc 3 iter 2840 took 7.2s
# loss:	0.12526	dev score:	0.8567
# Epoc 3 iter 2860 took 7.4s
# loss:	0.12631	dev score:	0.8600
# Epoc 3 iter 2880 took 7.3s
# loss:	0.12385	dev score:	0.8576
# Epoc 3 iter 2900 took 8.2s
# loss:	0.11164	dev score:	0.8602
# Epoc 3 iter 2920 took 7.3s
# loss:	0.12174	dev score:	0.8499
# Epoc 3 iter 2940 took 7.4s
# loss:	0.11749	dev score:	0.8572
# Epoc 3 iter 2960 took 7.8s
# loss:	0.12027	dev score:	0.8623	*** New best dev ***	test score:	0.8603
# Epoc 3 iter 2980 took 7.4s
# loss:	0.12863	dev score:	0.8580
# Epoc 3 iter 3000 took 7.5s
# loss:	0.12211	dev score:	0.8574
# Epoc 3 iter 3020 took 7.2s
# loss:	0.11652	dev score:	0.8606
